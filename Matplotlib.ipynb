# %% [markdown]
# # types of data
# numerical data
#
#
# categorical data

# %% [markdown]
# 1->column pr graph plot krna is univariant
#
#
# 2->columns pr graph plot krns is bivariant

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2D LINE PLOT

# %% [markdown]
# #conditions for 2d line plot
# 1. bivariate analysis
# 2. categorical->numerical and numerical->numerical
# 3.use case--> Time series data

# %%
#plot a simple line plot
price=[48000 , 54000 , 57000 , 49000 , 47000 , 45000]
year=[2015 , 2016 , 2017 , 2018 , 2019 , 2020]
plt.plot(year , price)

# %%
#importing data
df=pd.read_csv("C:/Users/shrut/OneDrive/Desktop/sharma-kohli.csv")
df.head()
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364

# %%
plt.plot(df["index"] , df["V Kohli"])
plt.title("virat Kohli runs")
plt.xlabel("yead")
plt.ylabel("Runs scored")
# Out:
# Text(0, 0.5, 'Runs scored')

# %%
plt.plot(df["index"] ,df["V Kohli"] , color="yellow" , linestyle="dashdot" , linewidth=3 ,marker='D')
plt.plot(df["index"] ,df["RG Sharma"] , color="blue" , linestyle="solid" , linewidth=2,marker="+")
plt.title("Virat Kohli VS Rohit Sharma")
plt.xlabel("year")
plt.ylabel("Runs Scored")
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
plt.plot(df["index"] ,df["V Kohli"] , color="yellow" , linestyle="dashdot" , linewidth=3 ,marker='D' , label="Virat")
plt.plot(df["index"] ,df["RG Sharma"] , color="blue" , linestyle="solid" , linewidth=2,marker="+" , label="Sharma")
plt.title("Virat Kohli VS Rohit Sharma")
plt.xlabel("year")
plt.ylabel("Runs Scored")
plt.legend()#to change parameter give inside brackets loc=""

# %%
plt.plot(df["index"] ,df["V Kohli"] , color="yellow" , linestyle="dashdot" , linewidth=3 ,marker='D' , label="Virat")
plt.plot(df["index"] ,df["RG Sharma"] , color="blue" , linestyle="solid" , linewidth=2,marker="+" , label="Sharma")
plt.title("Virat Kohli VS Rohit Sharma")
plt.xlabel("year")
plt.ylabel("Runs Scored")
plt.legend()#to change parameter give inside brackets loc=""
plt.grid()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Scatter plots

# %% [markdown]
# -->Bivariate analysis
#
# -->Numerical Vs Numerical
#
# -->use case--> Finding Correlation bet teo quantity

# %%
x= np.linspace(-10 , 10 , 50)
y= 10*x+3+np.random.randint(0 , 300 , 50)

# %%
plt.scatter(x , y)

# %%
df= pd.read_csv("C:/Users/shrut/OneDrive/Desktop/better.csv")

# %%
df.head(50)
# Out:
#             batter  runs        avg  strike_rate
# 0          V Kohli  6634  36.251366   125.977972
# 1         S Dhawan  6244  34.882682   122.840842
# 2        DA Warner  5883  41.429577   136.401577
# 3        RG Sharma  5881  30.314433   126.964594
# 4         SK Raina  5536  32.374269   132.535312
# 5   AB de Villiers  5181  39.853846   148.580442
# 6         CH Gayle  4997  39.658730   142.121729
# 7         MS Dhoni  4978  39.196850   130.931089
# 8       RV Uthappa  4954  27.522222   126.152279
# 9       KD Karthik  4377  26.852761   129.267572
# 10       G Gambhir  4217  31.007353   119.665153
# 11       AT Rayudu  4190  28.896552   124.148148
# 12       AM Rahane  4074  30.863636   117.575758
# 13        KL Rahul  3895  46.927711   132.799182
# 14       SR Watson  3880  30.793651   134.163209
# 15       MK Pandey  3657  29.731707   117.739858
# 16       SV Samson  3526  29.140496   132.407060
# 17      KA Pollard  3437  28.404959   140.457703
# ...

# %%
plt.scatter(df.head(50)['avg'] , df.head(50)['strike_rate'] , color="red" , marker="+")
plt.title("Avg and Strikrate analysis of top 50 Batsman")
plt.xlabel("Average")
plt.ylabel("Strikerate")
# Out:
# Text(0, 0.5, 'Strikerate')

# %%
import seaborn as sns
#seaborn dataset
tips= sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.scatter(tips['total_bill'] , tips['tip'], s=tips['size']*10)
plt.title("total bill and til analysis using size ")
plt.xlabel("total_bill")
plt.ylabel("tip")
# Out:
# Text(0, 0.5, 'tip')

# %%
#plot vs scatter
#plot is faster then scatter

# %% [markdown]
# # Bar Chart

# %% [markdown]
# can use for both Bivariate and Univariate
#
# numerical vs categorical
#
# use case Aggregate analysis of groups

# %%
#simple bar chart
children=[10 , 20 , 40 , 10 ,30]
colors=["red", "blue" ,"green" ,"yellow" ,"pink"]
plt.bar(colors ,children)
# Out:
# <BarContainer object of 5 artists>

# %%
#types-->vertical & horizontal(barh)

# %%
df=pd.read_csv("C:/Users/shrut/OneDrive/Desktop/batsman_season_record.csv")
df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(np.arange(df.shape[0])-0.2, df['2015'] , width=0.2)
plt.bar(np.arange(df.shape[0]), df['2016'] , width=0.2)
plt.bar(np.arange(df.shape[0])+0.2, df['2017'] , width=0.2)
plt.xticks(np.arange(df.shape[0] ), df['batsman'])
# Out:
# ([<matplotlib.axis.XTick at 0x2b0e3ba5a00>,
# ...
#  [Text(0, 0, 'AB de Villiers'),
#   Text(1, 0, 'DA Warner'),
#   Text(2, 0, 'MS Dhoni'),
#   Text(3, 0, 'RG Sharma'),
#   Text(4, 0, 'V Kohli')])

# %%
#problem
children=[10 , 20 , 40 , 10 ,30]
colors=["red red red red", "blue blue blue blue" ,"green green green green" ,"yellow yellow yellow yellow" ,"pink pink pink pink"]
plt.bar(colors ,children)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(colors , children)
plt.xticks(rotation='vertical')
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#stacked bar char
plt.bar(df['batsman'] , df["2015"] ,label="2015")
plt.bar(df['batsman'] , df["2016"] , bottom=df["2015"] , label="2016")
plt.bar(df['batsman'] , df["2017"] , bottom=df['2016']+df['2015'] , label="2017")
plt.legend()
